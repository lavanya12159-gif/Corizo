# %% [markdown]
# <a href="https://colab.research.google.com/github/lavanya12159-gif/Corizo/blob/main/spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LOGISTIC** **REGRESSION**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Initialize and train the Logistic Regression model
logistic_regression_model = LogisticRegression(max_iter=1000, random_state=42)
logistic_regression_model.fit(X_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_lr_new = logistic_regression_model.predict(X_test_scaled)

# Evaluate the model
accuracy_lr_new = accuracy_score(y_test, y_pred_lr_new)
report_lr_new = classification_report(y_test, y_pred_lr_new, output_dict=True)
cm_lr_new = confusion_matrix(y_test, y_pred_lr_new)

print(f"Logistic Regression Accuracy: {accuracy_lr_new:.4f}")
# Out:
# Logistic Regression Accuracy: 0.4671

# %% [markdown]
# ### Confusion Matrix for Logistic Regression

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Display the confusion matrix (using the pre-computed one for consistency if available, otherwise use new)
if 'cm_lr' in globals():
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues')
    plt.title('Logistic Regression Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()
else:
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_lr_new, annot=True, fmt='d', cmap='Blues')
    plt.title('Logistic Regression Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# %% [markdown]
# # **SUPPORT VECTOR CLASSIFICATION**

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Initialize and train the Support Vector Classifier model
svc_model = SVC(random_state=42)
svc_model.fit(X_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_svc = svc_model.predict(X_test_scaled)

# Evaluate the model
accuracy_svc = accuracy_score(y_test, y_pred_svc)
report_svc = classification_report(y_test, y_pred_svc, output_dict=True)
cm_svc = confusion_matrix(y_test, y_pred_svc)

print(f"Support Vector Classifier Accuracy: {accuracy_svc:.4f}")
# Out:
# Support Vector Classifier Accuracy: 0.5335

# %% [markdown]
# ### Confusion Matrix for Support Vector Classifier

# %%
# Display the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm_svc, annot=True, fmt='d', cmap='Blues')
plt.title('Support Vector Classifier Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# # **NAIVE BAYES CLASSIFICATION**

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Initialize and train the Gaussian Naive Bayes model
nb_model = GaussianNB()
nb_model.fit(X_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_nb = nb_model.predict(X_test_scaled)

# Evaluate the model
accuracy_nb = accuracy_score(y_test, y_pred_nb)
report_nb = classification_report(y_test, y_pred_nb, output_dict=True)
cm_nb = confusion_matrix(y_test, y_pred_nb)

print(f"Gaussian Naive Bayes Accuracy: {accuracy_nb:.4f}")
# Out:
# Gaussian Naive Bayes Accuracy: 0.4476

# %% [markdown]
# ### Confusion matrix for Gaussian Naive Bayes

# %%
# Display the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm_nb, annot=True, fmt='d', cmap='Blues')
plt.title('Gaussian Naive Bayes Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# # **K NEIGHBORS CLASSIFIER**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Initialize and train the K-Nearest Neighbors model
knn_model = KNeighborsClassifier()
knn_model.fit(X_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_knn = knn_model.predict(X_test_scaled)

# Evaluate the model
accuracy_knn = accuracy_score(y_test, y_pred_knn)
report_knn = classification_report(y_test, y_pred_knn, output_dict=True)
cm_knn = confusion_matrix(y_test, y_pred_knn)

print(f"K-Nearest Neighbors Accuracy: {accuracy_knn:.4f}")
# Out:
# K-Nearest Neighbors Accuracy: 0.4493

# %% [markdown]
# ### Confusion Matrix for K-Nearest Neighbors

# %%
# Display the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Blues')
plt.title('K-Nearest Neighbors Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# # **DECISON TREE CLASSIFIER**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Initialize and train the Decision Tree Classifier model
dtc_model = DecisionTreeClassifier(random_state=42)
dtc_model.fit(X_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_dtc = dtc_model.predict(X_test_scaled)

# Evaluate the model
accuracy_dtc = accuracy_score(y_test, y_pred_dtc)
report_dtc = classification_report(y_test, y_pred_dtc, output_dict=True)
cm_dtc = confusion_matrix(y_test, y_pred_dtc)

print(f"Decision Tree Classifier Accuracy: {accuracy_dtc:.4f}")
# Out:
# Decision Tree Classifier Accuracy: 0.4394

# %% [markdown]
# ### Confusion Matrix for Decision Tree Classifier

# %%
# Display the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm_dtc, annot=True, fmt='d', cmap='Blues')
plt.title('Decision Tree Classifier Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# # **RANDOM TREE CLASSIFIER**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Initialize and train the Random Forest Classifier model
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_rf = rf_model.predict(X_test_scaled)

# Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
report_rf = classification_report(y_test, y_pred_rf, output_dict=True)
cm_rf = confusion_matrix(y_test, y_pred_rf)

print(f"Random Forest Classifier Accuracy: {accuracy_rf:.4f}")
# Out:
# Random Forest Classifier Accuracy: 0.5448

# %% [markdown]
# ### Confusion Matrix for Random Forest Classifier

# %%
# Display the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues')
plt.title('Random Forest Classifier Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ## **COMPARISON OF THE ACCURACY**
#
# Random Forest Classifier: 0.5448
#
# Support Vector Classifier: 0.5335
#
# Logistic Regression: 0.4671
#
# K-Nearest Neighbors: 0.4493
#
# Gaussian Naive Bayes: 0.4476
#
# Decision Tree Classifier: 0.4394
#
# ## Based on these results, **the Random Forest Classifier** achieved the highest accuracy among all the models tested.
